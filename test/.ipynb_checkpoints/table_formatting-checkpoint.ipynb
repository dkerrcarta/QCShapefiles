# %%
from pathlib import Path
import pandas as pd
import geopandas as gpd
import numpy as np

BASE_DIR = Path('.').resolve().parent.joinpath('make_qc_shapefiles')
table = BASE_DIR.joinpath('classes.csv')
gdf = BASE_DIR.joinpath('test/test_data/test_data_out/WV_C18_L12/WV_C18_L12_points.shp')
df = pd.read_csv(table)
# Out:
#     Interp_num                                         Interp_cls
# 0         2011        Coastal plains on well-drained sandy ground
# 1         2012  Coastal plains on well-drained rocky or gravel...
# 2         2020                  Coastal sand sheets and low dunes
# 3         2030  Coastal cliffs, headlands, rocky slopes and wa...
# 4         3100             Coastal Sabkha, including sabkha matti
# 5         4110              Sand sheets and dunes with tree cover
# 6         4120             Sand sheets and dunes with shrub cover
# 7         4130       Sand sheets and dunes with dwarf shrub cover
# 8         4140  Sand sheets and dunes with perennial herbs and...
# 9         4200                                         Mega-dunes
# 10        5110        Gravel plains with distinct tree vegetation
# 11        5120          Gravel plains with dwarf shrub vegetation
# 12        5130               Gravel plains with sparse vegetation
# 13        5200                                      Inland sabkha
# 14        6100      Mountain slopes, screes, and associated wadis
# 15        6210               Jebels, (including mesas and burqas)
# 16        6220  Escarpments, lithified sand dunes, rocky expos...
# 17        6230        Wadis in open terrain and drainage channels
# 18        7100                              Semi-artificial lakes
# 19        8100                                        Plantations
# 20        8200                                           Farmland
# 21        8300                                    Livestock areas
# 22        8400                               Forestry plantations
# 23        9110                                 High Density Urban
# 24        9120                                  Low Density Urban
# 25        9210                                       Oil Industry
# 26        9220                            Airports and Aerodromes
# 27        9230                                         Port Areas
# 28        9240                                     Other industry
# 29        9300                                      Leisure areas
# 30        9400                                        Paved roads
# 31        9500                           Pipelines infrastructure
# 32        9600                                   Disturbed ground
# 33        1010              Mudflats and sand exposed at low tide
# 34        1020      Sheltered tidal flat with cyanobacterial mats
# 35        1030                                          Saltmarsh
# 36        1040                                          Mangroves
# 37        1050                                 Storm beach ridges
# 38        1060                                      Sandy beaches
# 39        1070                    Beach rock and gravelly beaches
# 40        1010              Mudflats and sand exposed at low tide
# 41        1020      Sheltered tidal flat with cyanobacterial mats
